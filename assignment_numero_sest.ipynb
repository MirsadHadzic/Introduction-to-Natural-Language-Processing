# %%
# Tokenize and tag the following sentence: They wind back the clock, while we chase after the wind. 
# What different pronunciations and parts-of-speech are involved? 

sent = "They wind back the clock, while we chase after the wind."
nltk.pos_tag(nltk.word_tokenize(sent))
# Out:
# [('They', 'PRP'),
#  ('wind', 'VBP'),
#  ('back', 'RB'),
#  ('the', 'DT'),
#  ('clock', 'NN'),
#  (',', ','),
#  ('while', 'IN'),
#  ('we', 'PRP'),
#  ('chase', 'VBP'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('wind', 'NN'),
#  ('.', '.')]

# %%
import nltk

# %%
# Train a unigram tagger and run it on some new text. Observe that some words are not 
# assigned a tag. Why not?

brown_tagged_sents = brown.tagged_sents(categories='news')
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)

test_text = ['hello', 'world', 'natural', 'language', 'processing']
unigram_tagger.tag(test_text)

# The words doesn't appear in the training text, and therefore the tagger can't speculate the 
# word's tag.
# Out:
# [('hello', None),
#  ('world', 'NN'),
#  ('natural', 'JJ'),
#  ('language', 'NN'),
#  ('processing', 'NN')]

# %%
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to C:\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
import brown
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import brown
#
# ModuleNotFoundError: No module named 'brown'

# %%
from nltk.corpus import brown

# %%
# Use sorted() and set() to get a sorted list of tags used in the Brown Corpus, removing duplicates.

list_of_tags = sorted(set([tag for (_, tag) in brown.tagged_words()]))

# %%
list_of_tags
# Out:
# ["'",
#  "''",
#  '(',
#  '(-HL',
#  ')',
#  ')-HL',
#  '*',
#  '*-HL',
#  '*-NC',
#  '*-TL',
#  ',',
#  ',-HL',
#  ',-NC',
#  ',-TL',
#  '--',
#  '---HL',
#  '.',
#  '.-HL',
#  '.-NC',
#  '.-TL',
#  ':',
#  ':-HL',
#  ':-TL',
#  'ABL',
#  'ABN',
#  'ABN-HL',
#  'ABN-NC',
#  'ABN-TL',
#  'ABX',
#  'AP',
#  'AP$',
#  'AP+AP-NC',
#  'AP-HL',
#  'AP-NC',
#  'AP-TL',
#  'AT',
#  'AT-HL',
#  'AT-NC',
#  'AT-TL',
#  'AT-TL-HL',
#  'BE',
#  'BE-HL',
#  'BE-TL',
#  'BED',
#  'BED*',
#  'BED-NC',
#  'BEDZ',
#  'BEDZ*',
#  'BEDZ-HL',
#  'BEDZ-NC',
#  'BEG',
#  'BEM',
#  'BEM*',
#  'BEM-NC',
#  'BEN',
#  'BEN-TL',
#  'BER',
#  'BER*',
#  'BER*-NC',
#  'BER-HL',
#  'BER-NC',
#  'BER-TL',
#  'BEZ',
#  'BEZ*',
#  'BEZ-HL',
#  'BEZ-NC',
#  'BEZ-TL',
#  'CC',
#  'CC-HL',
#  'CC-NC',
#  'CC-TL',
#  'CC-TL-HL',
#  'CD',
#  'CD$',
#  'CD-HL',
#  'CD-NC',
#  'CD-TL',
#  'CD-TL-HL',
#  'CS',
#  'CS-HL',
#  'CS-NC',
#  'CS-TL',
#  'DO',
#  'DO*',
#  'DO*-HL',
#  'DO+PPSS',
#  'DO-HL',
#  'DO-NC',
#  'DO-TL',
#  'DOD',
#  'DOD*',
#  'DOD*-TL',
#  'DOD-NC',
#  'DOZ',
#  'DOZ*',
#  'DOZ*-TL',
#  'DOZ-HL',
#  'DOZ-TL',
#  'DT',
#  'DT$',
#  'DT+BEZ',
#  'DT+BEZ-NC',
#  'DT+MD',
#  'DT-HL',
#  'DT-NC',
#  'DT-TL',
#  'DTI',
#  'DTI-HL',
#  'DTI-TL',
#  'DTS',
#  'DTS+BEZ',
#  'DTS-HL',
#  'DTX',
#  'EX',
#  'EX+BEZ',
#  'EX+HVD',
#  'EX+HVZ',
#  'EX+MD',
#  'EX-HL',
#  'EX-NC',
#  'FW-*',
#  'FW-*-TL',
#  'FW-AT',
#  'FW-AT+NN-TL',
#  'FW-AT+NP-TL',
#  'FW-AT-HL',
#  'FW-AT-TL',
#  'FW-BE',
#  'FW-BER',
#  'FW-BEZ',
#  'FW-CC',
#  'FW-CC-TL',
#  'FW-CD',
#  'FW-CD-TL',
#  'FW-CS',
#  'FW-DT',
#  'FW-DT+BEZ',
#  'FW-DTS',
#  'FW-HV',
#  'FW-IN',
#  'FW-IN+AT',
#  'FW-IN+AT-T',
#  'FW-IN+AT-TL',
#  'FW-IN+NN',
#  'FW-IN+NN-TL',
#  'FW-IN+NP-TL',
#  'FW-IN-TL',
#  'FW-JJ',
#  'FW-JJ-NC',
#  'FW-JJ-TL',
#  'FW-JJR',
#  'FW-JJT',
#  'FW-NN',
#  'FW-NN$',
#  'FW-NN$-TL',
#  'FW-NN-NC',
#  'FW-NN-TL',
#  'FW-NN-TL-NC',
#  'FW-NNS',
#  'FW-NNS-NC',
#  'FW-NNS-TL',
#  'FW-NP',
#  'FW-NP-TL',
#  'FW-NPS',
#  'FW-NPS-TL',
#  'FW-NR',
#  'FW-NR-TL',
#  'FW-OD-NC',
#  'FW-OD-TL',
#  'FW-PN',
#  'FW-PP$',
#  'FW-PP$-NC',
#  'FW-PP$-TL',
#  'FW-PPL',
#  'FW-PPL+VBZ',
#  'FW-PPO',
#  'FW-PPO+IN',
#  'FW-PPS',
#  'FW-PPSS',
#  'FW-PPSS+HV',
#  'FW-QL',
#  'FW-RB',
#  'FW-RB+CC',
#  'FW-RB-TL',
#  'FW-TO+VB',
#  'FW-UH',
#  'FW-UH-NC',
#  'FW-UH-TL',
#  'FW-VB',
#  'FW-VB-NC',
#  'FW-VB-TL',
#  'FW-VBD',
#  'FW-VBD-TL',
#  'FW-VBG',
#  'FW-VBG-TL',
#  'FW-VBN',
#  'FW-VBZ',
#  'FW-WDT',
#  'FW-WPO',
#  'FW-WPS',
#  'HV',
#  'HV*',
#  'HV+TO',
#  'HV-HL',
#  'HV-NC',
#  'HV-TL',
#  'HVD',
#  'HVD*',
#  'HVD-HL',
#  'HVG',
#  'HVG-HL',
#  'HVN',
#  'HVZ',
#  'HVZ*',
#  'HVZ-NC',
#  'HVZ-TL',
#  'IN',
#  'IN+IN',
#  'IN+PPO',
#  'IN-HL',
#  'IN-NC',
#  'IN-TL',
#  'IN-TL-HL',
#  'JJ',
#  'JJ$-TL',
#  'JJ+JJ-NC',
#  'JJ-HL',
#  'JJ-NC',
#  'JJ-TL',
#  'JJ-TL-HL',
#  'JJ-TL-NC',
#  'JJR',
#  'JJR+CS',
#  'JJR-HL',
#  'JJR-NC',
#  'JJR-TL',
#  'JJS',
#  'JJS-HL',
#  'JJS-TL',
#  'JJT',
#  'JJT-HL',
#  'JJT-NC',
#  'JJT-TL',
#  'MD',
#  'MD*',
#  'MD*-HL',
#  'MD+HV',
#  'MD+PPSS',
#  'MD+TO',
#  'MD-HL',
#  'MD-NC',
#  'MD-TL',
#  'NIL',
#  'NN',
#  'NN$',
#  'NN$-HL',
#  'NN$-TL',
#  'NN+BEZ',
#  'NN+BEZ-TL',
#  'NN+HVD-TL',
#  'NN+HVZ',
#  'NN+HVZ-TL',
#  'NN+IN',
#  'NN+MD',
#  'NN+NN-NC',
#  'NN-HL',
#  'NN-NC',
#  'NN-TL',
#  'NN-TL-HL',
#  'NN-TL-NC',
#  'NNS',
#  'NNS$',
#  'NNS$-HL',
#  'NNS$-NC',
#  'NNS$-TL',
#  'NNS$-TL-HL',
#  'NNS+MD',
#  'NNS-HL',
#  'NNS-NC',
#  'NNS-TL',
#  'NNS-TL-HL',
#  'NNS-TL-NC',
#  'NP',
#  'NP$',
#  'NP$-HL',
#  'NP$-TL',
#  'NP+BEZ',
#  'NP+BEZ-NC',
#  'NP+HVZ',
#  'NP+HVZ-NC',
#  'NP+MD',
#  'NP-HL',
#  'NP-NC',
#  'NP-TL',
#  'NP-TL-HL',
#  'NPS',
#  'NPS$',
#  'NPS$-HL',
#  'NPS$-TL',
#  'NPS-HL',
#  'NPS-NC',
#  'NPS-TL',
#  'NR',
#  'NR$',
#  'NR$-TL',
#  'NR+MD',
#  'NR-HL',
#  'NR-NC',
#  'NR-TL',
#  'NR-TL-HL',
#  'NRS',
#  'NRS-TL',
#  'OD',
#  'OD-HL',
#  'OD-NC',
#  'OD-TL',
#  'PN',
#  'PN$',
#  'PN+BEZ',
#  'PN+HVD',
#  'PN+HVZ',
#  'PN+MD',
#  'PN-HL',
#  'PN-NC',
#  'PN-TL',
#  'PP$',
#  'PP$$',
#  'PP$-HL',
#  'PP$-NC',
#  'PP$-TL',
#  'PPL',
#  'PPL-HL',
#  'PPL-NC',
#  'PPL-TL',
#  'PPLS',
#  'PPO',
#  'PPO-HL',
#  'PPO-NC',
#  'PPO-TL',
#  'PPS',
#  'PPS+BEZ',
#  'PPS+BEZ-HL',
#  'PPS+BEZ-NC',
#  'PPS+HVD',
#  'PPS+HVZ',
#  'PPS+MD',
#  'PPS-HL',
#  'PPS-NC',
#  'PPS-TL',
#  'PPSS',
#  'PPSS+BEM',
#  'PPSS+BER',
#  'PPSS+BER-N',
#  'PPSS+BER-NC',
#  'PPSS+BER-TL',
#  'PPSS+BEZ',
#  'PPSS+BEZ*',
#  'PPSS+HV',
#  'PPSS+HV-TL',
#  'PPSS+HVD',
#  'PPSS+MD',
#  'PPSS+MD-NC',
#  'PPSS+VB',
#  'PPSS-HL',
#  'PPSS-NC',
#  'PPSS-TL',
#  'QL',
#  'QL-HL',
#  'QL-NC',
#  'QL-TL',
#  'QLP',
#  'RB',
#  'RB$',
#  'RB+BEZ',
#  'RB+BEZ-HL',
#  'RB+BEZ-NC',
#  'RB+CS',
#  'RB-HL',
#  'RB-NC',
#  'RB-TL',
#  'RBR',
#  'RBR+CS',
#  'RBR-NC',
#  'RBT',
#  'RN',
#  'RP',
#  'RP+IN',
#  'RP-HL',
#  'RP-NC',
#  'RP-TL',
#  'TO',
#  'TO+VB',
#  'TO-HL',
#  'TO-NC',
#  'TO-TL',
#  'UH',
#  'UH-HL',
#  'UH-NC',
#  'UH-TL',
#  'VB',
#  'VB+AT',
#  'VB+IN',
#  'VB+JJ-NC',
#  'VB+PPO',
#  'VB+RP',
#  'VB+TO',
#  'VB+VB-NC',
#  'VB-HL',
#  'VB-NC',
#  'VB-TL',
#  'VBD',
#  'VBD-HL',
#  'VBD-NC',
#  'VBD-TL',
#  'VBG',
#  'VBG+TO',
#  'VBG-HL',
#  'VBG-NC',
#  'VBG-TL',
#  'VBN',
#  'VBN+TO',
#  'VBN-HL',
#  'VBN-NC',
#  'VBN-TL',
#  'VBN-TL-HL',
#  'VBN-TL-NC',
#  'VBZ',
#  'VBZ-HL',
#  'VBZ-NC',
#  'VBZ-TL',
#  'WDT',
#  'WDT+BER',
#  'WDT+BER+PP',
#  'WDT+BEZ',
#  'WDT+BEZ-HL',
#  'WDT+BEZ-NC',
#  'WDT+BEZ-TL',
#  'WDT+DO+PPS',
#  'WDT+DOD',
#  'WDT+HVZ',
#  'WDT-HL',
#  'WDT-NC',
#  'WP$',
#  'WPO',
#  'WPO-NC',
#  'WPO-TL',
#  'WPS',
#  'WPS+BEZ',
#  'WPS+BEZ-NC',
#  'WPS+BEZ-TL',
#  'WPS+HVD',
#  'WPS+HVZ',
#  'WPS+MD',
#  'WPS-HL',
#  'WPS-NC',
#  'WPS-TL',
#  'WQL',
#  'WQL-TL',
#  'WRB',
#  'WRB+BER',
#  'WRB+BEZ',
#  'WRB+BEZ-TL',
#  'WRB+DO',
#  'WRB+DOD',
#  'WRB+DOD*',
#  'WRB+DOZ',
#  'WRB+IN',
#  'WRB+MD',
#  'WRB-HL',
#  'WRB-NC',
#  'WRB-TL',
#  '``']

# %%
# Generate some statistics for tagged data to answer the following questions: 
# a. What proportion of word types are always assigned the same part-of-speech tag? 
# b. How many words are ambiguous, in the sense that they appear with at least two tags? 
# c. What percentage of word tokens in the Brown Corpus involve these ambiguous words? 

nltk.download('universal_tagset')

brown_tag = brown.tagged_words(tagset="universal")
cfd = nltk.ConditionalFreqDist(brown_tag)

conditions = cfd.conditions()

mono_tags = [condition for condition in conditions if len(cfd[condition]) == 1]

print(mono_tags)

proportion_mono_tags = len(mono_tags) / len(conditions)
print(proportion_mono_tags)

number_mono_tags = len(conditions) - len(mono_tags)
print(number_mono_tags)

total_brown_words = set(brown.words())
number_shared_words = [word for word in mono_tags if word in total_brown_words]
percen_brown = len(number_shared_words) / len(brown.words())
print(percen_brown)
# Out:
# [nltk_data] Downloading package universal_tagset to C:\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# ['The', 'Fulton', 'County', 'Jury', 'said', 'Friday', 'investigation', "Atlanta's", 'recent', 'election', 'produced', '``', "''", 'irregularities', 'took', '.', 'jury', 'term-end', 'presentments', 'City', 'Committee', 'over-all', 'deserves', 'thanks', 'Atlanta', 'manner', 'was', 'conducted', 'September-October', 'been', 'charged', 'Superior', 'Court', 'Durwood', 'Pye', 'investigate', 'possible', 'hard-fought', 'won', 'Mayor-nominate', 'Ivan', 'Allen', 'Jr.', 'handful', 'received', 'voters', 'city', 'did', "Georgia's", 'registration', 'laws', 'are', 'outmoded', 'inadequate', 'often', 'ambiguous', 'It', 'recommended', 'legislators', 'have', 'these', 'studied', 'revised', 'improving', 'grand', 'commented', 'other', 'topics', 'departments', 'operated', 'follow', 'generally', 'accepted', 'inure', 'both', 'governments', 'Merger', 'proposed', 'However', 'believes', 'two', 'offices', 'should', 'combined', 'achieve', 'greater', 'efficiency', 'reduce', 'administration', 'Department', 'lacking', 'clerical', 'policies', 'urged', 'problem', 'Implementation', 'automobile', 'title', 'law', 'also', 'outgoing', 'Legislature', 'provide', 'enabling', 'funds', 're-set', 'effective', 'implementation', 'effected', 'swipe', 'at', 'State', 'Welfare', "Department's", 'federal', 'granted', 'child', 'welfare', 'homes', 'This', 'items', 'assistance', 'seen', 'distribute', 'counties', 'exception', 'receives', 'none', 'money', 'jurors', 'they', 'realize', 'proportionate', 'distribution', 'disable', 'our', 'populous', 'Nevertheless', 'we', 'receive', 'portion', 'available', 'Failure', 'do', 'continue', 'disproportionate', 'taxpayers', "ordinary's", 'its', 'appointment', 'appraisers', 'guardians', 'administrators', 'fees', 'compensation', 'Wards', 'protected', 'found', 'incorporated', 'operating', 'procedures', 'recommendations', 'juries', 'Bar', 'Association', 'citizens', 'committee', 'These', 'actions', 'serve', 'protect', 'fact', "court's", 'wards', 'from', 'undue', 'appointed', 'elected', 'servants', 'unmeritorious', 'criticisms', 'Regarding', 'new', 'multi-million-dollar', 'airport', 'when', 'management', 'takes', 'Jan.', 'eliminate', 'political', 'not', 'added', 'periodic', 'surveillance', 'concessionaires', 'purpose', 'prices', 'reasonable', 'Ask', 'jail', 'deputies', 'Four', 'additional', 'employed', 'Jail', 'doctor', 'medical', 'intern', 'extern', 'night', 'weekend', 'duty', 'officials', 'legislation', 'establishment', 'equitable', 'pension', 'employes', 'praised', 'operation', 'Police', 'Tax', "Commissioner's", 'Office', 'Bellwood', 'Alpharetta', 'prison', 'farms', 'Grady', 'Hospital', 'Health', 'Mayor', 'William', 'B.', 'Hartsfield', 'filed', 'wife', 'Pearl', 'Williams', 'mental', 'cruelty', 'couple', 'married', 'Aug.', '1913', 'They', 'son', 'Berry', 'daughter', 'Mrs.', 'J.', 'M.', 'Cheshire', 'Griffin', 'Attorneys', 'mayor', 'amicable', 'property', 'settlement', 'agreed', 'listed', "mayor's", 'occupation', 'attorney', '71', '74', 'birth', 'Opelika', 'Ala.', 'lived', 'together', 'than', '637', 'Pelham', 'Rd.', 'Aj', 'Henry', 'L.', 'Bowden', 'interlude', '1937', 'career', 'goes', 'council', '1923', 'office', 'expires', 'He', 'succeeded', 'who', 'became', 'candidate', 'Sept.', '13', 'announced', 'would', 'reelection', 'Georgia', 'Republicans', 'encouragement', 'enter', '1962', "governor's", 'Wednesday', 'Robert', 'Snodgrass', 'GOP', 'chairman', 'held', 'Tuesday', 'Ridge', 'brought', 'enthusiastic', 'responses', 'audience', 'Party', 'Chairman', 'James', 'Dorsey', 'enthusiasm', '8', 'Savannah', 'Texas', 'Sen.', 'John', 'Tower', 'featured', 'speaker', 'warned', 'entering', 'governor', 'precincts', 'obtain', 'signatures', 'registered', 'Despite', 'unanimous', 'attended', 'When', 'asked', 'whether', 'wanted', 'voted', 'were', 'dissents', 'largest', 'courses', 'taken', 'Five', 'cent', 'each', 'county', 'requesting', 'allowed', 'candidates', 'ballot', 'unit', 'system', 'opposes', 'platform', 'Sam', 'Caldwell', 'Highway', 'relations', 'director', 'resigned ...
# 0.9358510087946198
# 3596
# 0.045178575119360104
