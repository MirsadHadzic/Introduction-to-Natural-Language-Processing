# %%
import nltk
nltk.download('book')
from nltk.book import *
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to C:\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to C:\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to C:\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to C:\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to C:\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# ...

# %%
# How many words are there in text5? How many distinct words are there?

# print(len(text5))
# print(set(text5))
# print(sorted(set(text5)))
print(len(sorted(set(text5))))
# 6066 answer
print(len(set(text5)))
# Out:
# 6066
# 6066

# %%
# Find the collocations in text5.

text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %%
# Find 5 most occurring words in text2.
# from nltk import Freq

freq_dist = FreqDist(text2)
# print(freq_dist.max())
# print(sorted([w for w in set(text2) if freq_dist[w] > 3500])) 
# ovo iznad moze ali je ovo varanje prakticki..., sad, ne znam, je l se tacka i zarez racunaju pod "rijeci" u ovom slucaju
top_words = freq_dist.most_common(5)
print(top_words)
# sorted(set(text5))
# Out:
# [(',', 9397), ('to', 4063), ('.', 3975), ('the', 3861), ('of', 3565)]

# %%
#import nltk
#from nltk import FreqDist
#from nltk.tokenize import word_tokenize

# Sample text


# Tokenize the text
#words = word_tokenize(text2)

# Create a frequency distribution
#freq_dist = FreqDist(words)

# Find the 5 most common words
#top_words = freq_dist.most_common(5)

# Print the results
#for word, frequency in top_words:
    #print("f{word}: {frequency}")
   # print(word, frequency)

# %%
# Find how many words from text2 ends with ‘ly’

task = sorted([w for w in text2 if w.endswith('ly')])
# for word in task:
# print (task)
# or 
for word in task:
    print (word)
# Out:
# Beautifully
# Certainly
# Certainly
# Certainly
# Certainly
# Certainly
# Certainly
# Certainly
# Certainly
# Certainly
# Certainly
# Certainly
# Certainly
# Early
# Folly
# Fortunately
# Fortunately
# Fortunately
# Luckily
# Only
# Only
# Only
# Only
# Only
# Really
# Really
# Sally
# Scarcely
# Scarcely
# Sincerely
# Surely
# Surely
# Surely
# Undoubtedly
# Undoubtedly
# Undoubtedly
# abominably
# abruptly
# abruptly
# abruptly
# absolutely
# absolutely
# absolutely
# absolutely
# absolutely
# absolutely
# absolutely
# absolutely
# absolutely
# absolutely
# abundantly
# acceptably
# accidentally
# accidentally
# accidentally
# accidentally
# accidentally
# accidently
# accordingly
# accordingly
# accordingly
# accurately
# actually
# actually
# actually
# actually
# actually
# actually
# acutely
# affectedly
# affectedly
# affectionately
# affectionately
# alternately
# alternately
# amazingly
# amiably
# amply
# amply
# amply
# angrily
# anxiously
# anxiously
# anxiously
# ...

# %%
# Calculate lexical richness of tex2

len(set(text2)) / len(text2)
# Out:
# 0.04826383002768831

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 dirname()
#
# NameError: name 'dirname' is not defined
