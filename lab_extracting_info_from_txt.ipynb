# %% [markdown]
# Chunking involves grouping together individual pieces of information from a sentence, such as nouns, verbs, adjectives, and adverbs, into larger units known as chunks. The most common type of chunking is noun phrase (NP) chunking, which involves identifying and extracting noun phrases from a sentence, such as "the cat," "a book," or "my friend." Another type of chunking is verb phrase (VP) chunking, which involves identifying and extracting verb phrases from a sentence, such as "ate breakfast," "is running," or "will sing."
#
# Noun phrases are part of speech patterns that include a noun. They can also include whatever other parts of speech make grammatical sense, and can include multiple nouns. Some common noun phrase patterns are:
#
#     Noun
#     Noun-Noun..… -Noun
#     Adjective(s)-Noun
#     Verb-(Adjectives-)Noun
#
# A noun phrase consists of a noun or pronoun, which is called the head, and any dependent words before or after the head.
#
# Chunking are important techniques in NLP because they allow us to extract meaningful information from text data. By identifying and grouping together chunks of information, we can analyze patterns and relationships within the text and extract relevant insights.
#
# POS Example
#
# CC coordinating conjunction and
# CD cardinal number 1, third
# DT determiner the
# EX existential there there is
# FW foreign word d’hoevre
# IN preposition/subordinating conjunction in, of, like
# JJ adjective big
# JJR adjective, comparative bigger
# JJS adjective, superlative biggest
# LS list marker 1)
# MD modal could, will
# NN noun, singular or mass door
# NNS noun plural doors
# NNP proper noun, singular John
# NNPS proper noun, plural Vikings
# PDT predeterminer both the boys
# POS possessive ending friend's
# PRP personal pronoun I, he, it
# RB adverb however, usually, naturally, here, good
# RBR adverb, comparative better
# RBS adverb, superlative best
# RP particle give up
# TO to to go, to him
# UH interjection uhhuhhuhh
# VB verb, base form take
# VBD verb, past tense took
# VBG verb, gerund/present participle taking
# VBN verb, past participle taken
# VBP verb, sing. present, non-3d take
# VBZ verb, 3rd person sing. present takes
# WDT wh-determiner which
# WP wh-pronoun who, what
# WP$ possessive wh-pronoun whose
# WRB wh-abverb where, when

# %%
#1. Write a tag pattern to match noun phrases containing plural
#head nouns, e.g., many/JJ researchers/NNS, two/CD weeks/NNS,
#both/DT new/JJ positions/NNS. Try to do this by generalizing
#the tag pattern that handled singular noun phrases.

import nltk
import re
from nltk import word_tokenize, pos_tag

textchunk = [("many", "JJ"), ("researchers", "NNS"), ("two", "CD"), ("weeks", "NNS"), ("both","DT"), ("new", "JJ"), ("positions", "NNS")]
corpus = nltk.RegexpParser("NP:{<DT>?<CD>?<JJ>*<NNS>}")

print(corpus.parse(textchunk))
for chunk in corpus.parse(textchunk):
    print(chunk)
# Out:
# (S
#   (NP many/JJ researchers/NNS)
#   (NP two/CD weeks/NNS)
#   (NP both/DT new/JJ positions/NNS))
# (NP many/JJ researchers/NNS)
# (NP two/CD weeks/NNS)
# (NP both/DT new/JJ positions/NNS)

# %%
#Pick one of the three chunk types in the CoNLL-2000 Chunking Corpus.
#Inspect the data and try to observe any patterns in the POS tag sequences
#that make up this kind of chunk. Develop a simple chunker using the regular
#expression chunker nltk.RegexpParser. Discuss any tag sequences that are difficult to chunk reliably.

nltk.download('conll2000')
from nltk.corpus import conll2000

for i in range(20):
    print(i, conll2000.chunked_sents('train.txt', chunk_types = ['VP'])[i])
# Out:
# 0 (S
#   Confidence/NN
#   in/IN
#   the/DT
#   pound/NN
#   (VP is/VBZ widely/RB expected/VBN to/TO take/VB)
#   another/DT
#   sharp/JJ
#   dive/NN
#   if/IN
#   trade/NN
#   figures/NNS
#   for/IN
#   September/NNP
#   ,/,
#   due/JJ
#   for/IN
#   release/NN
#   tomorrow/NN
#   ,/,
#   (VP fail/VB to/TO show/VB)
#   a/DT
#   substantial/JJ
#   improvement/NN
#   from/IN
#   July/NNP
#   and/CC
#   August/NNP
#   's/POS
#   near-record/JJ
#   deficits/NNS
#   ./.)
# 1 (S
#   Chancellor/NNP
#   of/IN
#   the/DT
#   Exchequer/NNP
#   Nigel/NNP
#   Lawson/NNP
#   's/POS
#   restated/VBN
#   commitment/NN
#   to/TO
#   a/DT
#   firm/NN
#   monetary/JJ
#   policy/NN
#   (VP has/VBZ helped/VBN to/TO prevent/VB)
#   a/DT
#   freefall/NN
#   in/IN
#   sterling/NN
#   over/IN
#   the/DT
#   past/JJ
#   week/NN
#   ./.)
# 2 (S
#   But/CC
#   analysts/NNS
#   (VP reckon/VBP)
#   underlying/VBG
#   support/NN
#   for/IN
#   sterling/NN
#   (VP has/VBZ been/VBN eroded/VBN)
#   by/IN
#   the/DT
#   chancellor/NN
#   's/POS
#   failure/NN
#   (VP to/TO announce/VB)
#   any/DT
#   new/JJ
#   policy/NN
#   measures/NNS
#   in/IN
#   his/PRP$
#   Mansion/NNP
#   House/NNP
#   speech/NN
#   last/JJ
#   Thursday/NNP
#   ./.)
# 3 (S
#   This/DT
#   (VP has/VBZ increased/VBN)
#   the/DT
#   risk/NN
#   of/IN
#   the/DT
#   government/NN
#   (VP being/VBG forced/VBN to/TO increase/VB)
#   base/NN
#   rates/NNS
#   to/TO
#   16/CD
#   %/NN
#   from/IN
#   their/PRP$
#   current/JJ
#   15/CD
#   %/NN
#   level/NN
#   (VP to/TO defend/VB)
#   the/DT
#   pound/NN
#   ,/,
#   economists/NNS
#   and/CC
#   foreign/JJ
#   exchange/NN
#   market/NN
#   analysts/NNS
#   (VP say/VBP)
#   ./.)
# 4 (S
#   ``/``
#   The/DT
#   risks/NNS
#   for/IN
#   sterling/NN
#   of/IN
#   a/DT
#   bad/JJ
#   trade/NN
#   figure/NN
#   (VP are/VBP)
#   very/RB
#   heavily/RB
#   on/IN
#   the/DT
#   down/JJ
#   side/NN
#   ,/,
#   ''/''
#   (VP said/VBD)
#   Chris/NNP
#   Dillow/NNP
#   ,/,
#   senior/JJ
#   U.K./NNP
#   economist/NN
#   at/IN
#   Nomura/NNP
#   Research/NNP
#   Institute/NNP
#   ./.)
# 5 (S
#   ``/``
#   If/IN
#   there/EX
#   (VP is/VBZ)
#   another/DT
#   bad/JJ
#   trade/NN
#   number/NN
#   ,/,
#   there/EX
#   (VP could/MD be/VB)
#   an/DT
#   awful/JJ
#   lot/NN
#   of/IN
#   pressure/NN
#   ,/,
#   ''/''
#   (VP noted/VBD)
#   Simon/NNP
#   Briscoe/NNP
#   ,/,
#   U.K./NNP
#   economist/NN
#   for/IN
#   Midland/NNP
#   Montagu/NNP
#   ,/,
#   a/DT
#   unit/NN
#   of/IN
#   Midland/NNP
#   Bank/NNP
#   PLC/NNP
#   ./.)
# 6 (S
#   Forecasts/NNS
#   for/IN
#   the/DT
#   trade/NN
#   figures/NNS
#   (VP range/VBP)
#   widely/RB
#   ,/,
#   but/CC
#   few/JJ
#   economists/NNS
#   (VP expect/VBP)
#   the/DT
#   data/NNS
#   (VP to/TO show/VB)
#   a/DT
#   very/RB
#   marked/VBN
#   improvement/NN
#   from/IN
#   the/DT
#   #/#
#   2/CD
#   billion/CD
#   -LRB-/(
#   $/$
#   3.2/CD
#   billion/CD
#   -RRB-/)
#   deficit/NN
#   in/IN
#   the/DT
#   current/JJ
#   account/NN
#   (VP reported/VBD)
#   for/IN
#   August/NNP
#   ./.)
# 7 (S
#   The/DT
#   August/NNP
#   deficit/NN
#   and/CC
#   the/DT
#   #/#
#   2.2/CD
#   billion/CD
#   gap/NN
#   (VP registered/VBN)
#   in/IN
#   July/NNP
#   (VP are/VBP topped/VBN)
#   only/RB
#   by/IN
#   the/DT
#   #/#
#   2.3/CD
#   billion/CD
#   deficit/NN
#   of/IN
#   October/NNP
#   1988/CD
#   ./.)
# 8 (S
#   Sanjay/NNP
#   Joshi/NNP
#   ,/,
#   European/JJ
#   economist/NN
#   at/IN
#   Baring/NNP
#   Brothers/NNPS
#   &/CC
#   Co./NNP
#   ,/,
#   (VP said/VBD)
#   there/EX
#   (VP is/VBZ)
#   no/DT
#   sign/NN
#   that/IN
#   Britain/NNP
#   's/POS
#   manufacturing/NN
#   industry/NN
#   (VP is/VBZ transforming/VBG)
#   itself/PRP
#   (VP to/TO boost/VB)
#   exports/NNS
#   ./.)
# 9 (S
#   At/IN
#   the/DT
#   same/JJ
#   time/NN
#   ,/,
#   he/PRP
#   (VP remains/VBZ)
#   fairly/RB
#   pessimistic/JJ
#   about/IN
#   the/DT
#   outlook/NN
#   for/IN
#   imports/NNS
#   ,/,
#   given/VBN
#   continued/VBD
#   high/JJ
#   consumer/NN
#   and/CC
#   capital/NN
#   goods/NNS
#   inflows/NNS
#   ./.)
# 10 (S
#   He/PRP
#   (VP reckons/VBZ)
#   the/DT
#   current/JJ
#   account/NN
#   deficit/NN
#   (VP will/MD narrow/VB)
#   to/TO
#   only/RB
#   #/#
#   1.8/CD
#   billion/CD
#   in/IN
#   September/NNP
#   ./.)
# 11 (S
#   However/RB
#   ,/,
#   Mr./NNP
#   Dillow/NNP
#   (VP said/VBD)
#   he/PRP
#   (VP believes/VBZ)
#   that/IN
#   a/DT
#   reduction/NN
#   in/IN
#   raw/JJ
#   material/NN
#   stockbuilding/VBG
#   by/IN
#   industry/NN
#   (VP could/MD lead/VB)
#   to/TO
#   a/DT
#   sharp/JJ
#   drop/NN
#   in/IN
#   imports/NNS
#   ./.)
# 12 (S
#   Combined/VBN
#   with/IN
#   at/IN
#   least/JJS
#   some/DT
#   rebound/NN
#   in/IN
#   exports/NNS
#   after/IN
#   August/NNP
#   's/POS
#   unexpected/JJ
#   decline/NN
#   ,/,
#   the/DT
#   deficit/NN
#   (VP could/MD narrow/VB)
#   to/TO
#   as/RB
#   little/JJ
#   as/IN
#   #/#
#   1.3/CD
#   billion/CD
#   ./.)
# 13 (S
#   Mr./NNP
#   Briscoe/NNP
#   ,/,
#   who/WP
#   also/RB
#   (VP forecasts/VBZ)
#   a/DT
#   #/#
#   1.3/CD
#   billion/CD
#   current/JJ
#   account/NN
#   gap/NN
#   ,/,
#   (VP warns/VBZ)
#   that/IN
#   even/RB
#   if/IN
#   the/DT
#   trade/NN
#   figures/NNS
#   (VP are/VBP)
#   bullish/JJ
#   for/IN
#   sterling/NN
#   ,/,
#   the/DT
#   currency/NN
#   (VP wo/MD n't/RB advance/VB)
#   much/JJ
#   because/IN
#   investors/NNS
#   (VP will/MD want/VB to/TO see/VB)
#   further/JJ
#   evidence/NN
#   of/IN
#   the/DT
#   turnaround/NN
#   before/IN
#   (VP adjusting/VBG)
#   positions/NNS
#   ./.)
# 14 (S
#   Nevertheless/RB
#   ,/,
#   he/PRP
#   (VP noted/VBD)
#   ,/,
#   ``/``
#   No/DT
#   one/PRP
#   (VP will/MD want/VB to/TO go/VB)
#   into/IN
#   the/DT
#   trade/NN
#   figures/NNS
#   without/IN
#   a/DT
#   flat/JJ
#   position/NN
#   ''/''
#   in/IN
#   the/DT
#   pound/NN
#   ./.)
# 15 (S
#   Meanwhile/RB
#   ,/,
#   overall/JJ
#   evidence/NN
#   on/IN
#   the/DT
#   economy/NN
#   (VP remains/VBZ)
#   fairly/RB
#   clouded/VBN
#   ./.)
# 16 (S
#   In/IN
#   his/PRP$
#   Mansion/NNP
#   House/NNP
#   speech/NN
#   ,/,
#   Mr./NNP
#   Lawson/NNP
#   (VP warned/VBD)
#   that/IN
#   a/DT
#   further/JJ
#   slowdown/NN
#   (VP can/MD be/VB expected/VBN)
#   as/IN
#   the/DT
#   impact/NN
#   of/IN
#   the/DT
#   last/JJ
#   rise/NN
#   in/IN
#   interest/NN
#   rates/NNS
#   earlier/RBR
#   this/DT
#   month/NN
#   (VP takes/VBZ)
#   effect/NN
#   ./.)
# 17 (S
#   U.K./JJ
#   base/NN
#   rates/NNS
#   (VP are/VBP)
#   at/IN
#   their/PRP$
#   highest/JJS
#   level/NN
#   in/IN
#   eight/CD
#   years/NNS
#   ./.)
# 18 (S
#   But/CC
#   consumer/NN
#   expenditure/NN
#   data/NNS
#   (VP released/VBD)
#   Friday/NNP
#   (VP do/VBP n't/RB suggest/VB)
#   that/IN
#   the/DT
#   U.K./NNP
#   economy/NN
#   (VP is/VBZ slowing/VBG)
#   that/DT
#   quickly/RB
#   ./.)
# 19 (S
#   The/DT
#   figures/NNS
#   (VP show/VBP)
#   that/DT
#   spending/NN
#   (VP rose/VBD)
#   0.1/CD
#   %/NN
#   in/IN
#   the/DT
#   third/JJ
#   quarter/NN
#   from/IN
#   the/DT
#   second/JJ
#   quarter/NN
#   and/CC
#   (VP was/VBD)
#   up/IN
#   3.8/CD
#   %/NN
#   from/IN
#   a/DT
#   year/NN
#   ago/RB
#   ./.)
# [nltk_data] Downloading package conll2000 to C:\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!

# %% [markdown]
# The most common patterns:
#
# (VP rose/VBD)
#
# (VP are/VBP topped/VBN) (VP has/VBZ been/VBN eroded/VBN)
#
# (VP could/MD be/VB)
#
# (VP has/VBZ helped/VBN to/TO prevent/VB) (VP being/VBG forced/VBN to/TO increase/VB)
#
# (VP is/VBZ widely/RB expected/VBN to/TO take/VB)

# %%
grammar = r"VP: {<[VRMT].*>+}" # {<VB.>?<RB>*<MD>?<VB.>?<TO>?<VB.>} or {<VB.>?<RB.>*<MD>?<VB.>?<TO>?<VB.>} or {<VB.>?<RB>*<MD>?<VB.>?<TO>?<MD>?<RB>*<VB.>}
cp = nltk.RegexpParser(grammar)

for i in range(20):
  test_sent =  conll2000.chunked_sents('train.txt', chunk_types = ['VP'])[i]
  print(i, print(cp.parse(test_sent)))
# Out:
# (S
#   Confidence/NN
#   in/IN
#   the/DT
#   pound/NN
#   (VP (VP is/VBZ widely/RB expected/VBN to/TO take/VB))
#   another/DT
#   sharp/JJ
#   dive/NN
#   if/IN
#   trade/NN
#   figures/NNS
#   for/IN
#   September/NNP
#   ,/,
#   due/JJ
#   for/IN
#   release/NN
#   tomorrow/NN
#   ,/,
#   (VP (VP fail/VB to/TO show/VB))
#   a/DT
#   substantial/JJ
#   improvement/NN
#   from/IN
#   July/NNP
#   and/CC
#   August/NNP
#   's/POS
#   near-record/JJ
#   deficits/NNS
#   ./.)
# 0 None
# (S
#   Chancellor/NNP
#   of/IN
#   the/DT
#   Exchequer/NNP
#   Nigel/NNP
#   Lawson/NNP
#   's/POS
#   (VP restated/VBN)
#   commitment/NN
#   (VP to/TO)
#   a/DT
#   firm/NN
#   monetary/JJ
#   policy/NN
#   (VP (VP has/VBZ helped/VBN to/TO prevent/VB))
#   a/DT
#   freefall/NN
#   in/IN
#   sterling/NN
#   over/IN
#   the/DT
#   past/JJ
#   week/NN
#   ./.)
# 1 None
# (S
#   But/CC
#   analysts/NNS
#   (VP (VP reckon/VBP) underlying/VBG)
#   support/NN
#   for/IN
#   sterling/NN
#   (VP (VP has/VBZ been/VBN eroded/VBN))
#   by/IN
#   the/DT
#   chancellor/NN
#   's/POS
#   failure/NN
#   (VP (VP to/TO announce/VB))
#   any/DT
#   new/JJ
#   policy/NN
#   measures/NNS
#   in/IN
#   his/PRP$
#   Mansion/NNP
#   House/NNP
#   speech/NN
#   last/JJ
#   Thursday/NNP
#   ./.)
# 2 None
# (S
#   This/DT
#   (VP (VP has/VBZ increased/VBN))
#   the/DT
#   risk/NN
#   of/IN
#   the/DT
#   government/NN
#   (VP (VP being/VBG forced/VBN to/TO increase/VB))
#   base/NN
#   rates/NNS
#   (VP to/TO)
#   16/CD
#   %/NN
#   from/IN
#   their/PRP$
#   current/JJ
#   15/CD
#   %/NN
#   level/NN
#   (VP (VP to/TO defend/VB))
#   the/DT
#   pound/NN
#   ,/,
#   economists/NNS
#   and/CC
#   foreign/JJ
#   exchange/NN
#   market/NN
#   analysts/NNS
#   (VP (VP say/VBP))
#   ./.)
# 3 None
# (S
#   ``/``
#   The/DT
#   risks/NNS
#   for/IN
#   sterling/NN
#   of/IN
#   a/DT
#   bad/JJ
#   trade/NN
#   figure/NN
#   (VP (VP are/VBP) very/RB heavily/RB)
#   on/IN
#   the/DT
#   down/JJ
#   side/NN
#   ,/,
#   ''/''
#   (VP (VP said/VBD))
#   Chris/NNP
#   Dillow/NNP
#   ,/,
#   senior/JJ
#   U.K./NNP
#   economist/NN
#   at/IN
#   Nomura/NNP
#   Research/NNP
#   Institute/NNP
#   ./.)
# 4 None
# (S
#   ``/``
#   If/IN
#   there/EX
#   (VP (VP is/VBZ))
#   another/DT
#   bad/JJ
#   trade/NN
#   number/NN
#   ,/,
#   there/EX
#   (VP (VP could/MD be/VB))
#   an/DT
#   awful/JJ
#   lot/NN
#   of/IN
#   pressure/NN
#   ,/,
#   ''/''
#   (VP (VP noted/VBD))
#   Simon/NNP
#   Briscoe/NNP
#   ,/,
#   U.K./NNP
#   economist/NN
#   for/IN
#   Midland/NNP
#   Montagu/NNP
#   ,/,
#   a/DT
#   unit/NN
#   of/IN
#   Midland/NNP
#   Bank/NNP
#   PLC/NNP
#   ./.)
# 5 None
# (S
#   Forecasts/NNS
#   for/IN
#   the/DT
#   trade/NN
#   figures/NNS
#   (VP (VP range/VBP) widely/RB)
#   ,/,
#   but/CC
#   few/JJ
#   economists/NNS
#   (VP (VP expect/VBP))
#   the/DT
#   data/NNS
#   (VP (VP to/TO show/VB))
#   a/DT
#   (VP very/RB marked/VBN)
#   improvement/NN
#   from/IN
#   the/DT
#   #/#
#   2/CD
#   billion/CD
#   -LRB-/(
#   $/$
#   3.2/CD
#   billion/CD
#   -RRB-/)
#   deficit/NN
#   in/IN
#   the/DT
#   current/JJ
#   account/NN
#   (VP (VP reported/VBD))
#   for/IN
#   August/NNP
#   ./.)
# 6 None
# (S
#   The/DT
#   August/NNP
#   deficit/NN
#   and/CC
#   the/DT
#   #/#
#   2.2/CD
#   billion/CD
#   gap/NN
#   (VP (VP registered/VBN))
#   in/IN
#   July/NNP
#   (VP (VP are/VBP topped/VBN) only/RB)
#   by/IN
#   the/DT
#   #/#
#   2.3/CD
#   billion/CD
#   deficit/NN
#   of/IN
#   October/NNP
#   1988/CD
#   ./.)
# 7 None
# (S
#   Sanjay/NNP
#   Joshi/NNP
#   ,/,
#   European/JJ
#   economist/NN
#   at/IN
#   Baring/NNP
#   Brothers/NNPS
#   &/CC
#   Co./NNP
#   ,/,
#   (VP (VP said/VBD))
#   there/EX
#   (VP (VP is/VBZ))
#   no/DT
#   sign/NN
#   that/IN
#   Britain/NNP
#   's/POS
#   manufacturing/NN
#   industry/NN
#   (VP (VP is/VBZ transforming/VBG))
#   itself/PRP
#   (VP (VP to/TO boost/VB))
#   exports/NNS
#   ./.)
# 8 None
# (S
#   At/IN
#   the/DT
#   same/JJ
#   time/NN
#   ,/,
#   he/PRP
#   (VP (VP remains/VBZ) fairly/RB)
#   pessimistic/JJ
#   about/IN
#   the/DT
#   outlook/NN
#   for/IN
#   imports/NNS
#   ,/,
#   (VP given/VBN continued/VBD)
#   high/JJ
#   consumer/NN
#   and/CC
#   capital/NN
#   goods/NNS
#   inflows/NNS
#   ./.)
# 9 None
# (S
#   He/PRP
#   (VP (VP reckons/VBZ))
#   the/DT
#   current/JJ
#   account/NN
#   deficit/NN
#   (VP (VP will/MD narrow/VB) to/TO only/RB)
#   #/#
#   1.8/CD
#   billion/CD
#   in/IN
#   September/NNP
#   ./.)
# 10 None
# (S
#   (VP However/RB)
#   ,/,
#   Mr./NNP
#   Dillow/NNP
#   (VP (VP said/VBD))
#   he/PRP
#   (VP (VP believes/VBZ))
#   that/IN
#   a/DT
#   reduction/NN
#   in/IN
#   raw/JJ
#   material/NN
#   (VP stockbuilding/VBG)
#   by/IN
#   industry/NN
#   (VP (VP could/MD lead/VB) to/TO)
#   a/DT
#   sharp/JJ
#   drop/NN
#   in/IN
#   imports/NNS
#   ./.)
# 11 None
# (S
#   (VP Combined/VBN)
#   with/IN
#   at/IN
#   least/JJS
#   some/DT
#   rebound/NN
#   in/IN
#   exports/NNS
#   after/IN
#   August/NNP
#   's/POS
#   unexpected/JJ
#   decline/NN
#   ,/,
#   the/DT
#   deficit/NN
#   (VP (VP could/MD narrow/VB) to/TO as/RB)
#   little/JJ
#   as/IN
#   #/#
#   1.3/CD
#   billion/CD
#   ./.)
# 12 None
# (S
#   Mr./NNP
#   Briscoe/NNP
#   ,/,
#   who/WP
#   (VP also/RB (VP forecasts/VBZ))
#   a/DT
#   #/#
#   1.3/CD
#   billion/CD
#   current/JJ
#   account/NN
#   gap/NN
#   ,/,
#   (VP (VP warns/VBZ))
#   that/IN
#   (VP even/RB)
#   if/IN
#   the/DT
#   trade/NN
#   figures/NNS
#   (VP (VP are/VBP))
#   bullish/JJ
#   for/IN
#   sterling/NN
#   ,/,
#   the/DT
#   currency/NN
#   (VP (VP wo/MD n't/RB advance/VB))
#   much/JJ
#   because/IN
#   investors/NNS
#   (VP (VP will/MD want/VB to/TO see/VB))
#   further/JJ
#   evidence/NN
#   of/IN
#   the/DT
#   turnaround/NN
#   before/IN
#   (VP (VP adjusting/VBG))
#   positions/NNS
#   ./.)
# 13 None
# (S
#   (VP Nevertheless/RB)
#   ,/,
#   he/PRP
#   (VP (VP noted/VBD))
#   ,/,
#   ``/``
#   No/DT
#   one/PRP
#   (VP (VP will/MD want/VB to/TO go/VB))
#   into/IN
#   the/DT
#   trade/NN
#   figures/NNS
#   without/IN
#   a/DT
#   flat/JJ
#   position/NN
#   ''/''
#   in/IN
#   the/DT
#   pound/NN
#   ./.)
# 14 None
# (S
#   (VP Meanwhile/RB)
#   ,/,
#   overall/JJ
#   evidence/NN
#   on/IN
#   the/DT
#   economy/NN
#   (VP (VP remains/VBZ) fairly/RB clouded/VBN)
#   ./.)
# 15 None
# (S
#   In/IN
#   his/PRP$
#   Mansion/NNP
#   House/NNP
#   speech/NN
#   ,/,
#   Mr./NNP
#   Lawson/NNP
#   (VP (VP warned/VBD))
#   that/IN
#   a/DT
#   further/JJ
#   slowdown/NN
#   (VP (VP can/MD be/VB expected/VBN))
#   as/IN
#   the/DT
#   impact/NN
#   of/IN
#   the/DT
#   last/JJ
#   rise/NN
#   in/IN
#   interest/NN
#   rates/NNS
#   (VP earlier/RBR)
#   this/DT
#   month/NN
#   (VP (VP takes/VBZ))
#   effect/NN
#   ./.)
# 16 None
# (S
#   U.K./JJ
#   base/NN
#   rates/NNS
#   (VP (VP are/VBP))
#   at/IN
#   their/PRP$
#   highest/JJS
#   level/NN
#   in/IN
#   eight/CD
#   years/NNS
#   ./.)
# 17 None
# (S
#   But/CC
#   consumer/NN
#   expenditure/NN
#   data/NNS
#   (VP (VP released/VBD))
#   Friday/NNP
#   (VP (VP do/VBP n't/RB suggest/VB))
#   that/IN
#   the/DT
#   U.K./NNP
#   economy/NN
#   (VP (VP is/VBZ slowing/VBG))
#   that/DT
#   (VP quickly/RB)
#   ./.)
# 18 None
# (S
#   The/DT
#   figures/NNS
#   (VP (VP show/VBP))
#   that/DT
#   spending/NN
#   (VP (VP rose/VBD))
#   0.1/CD
#   %/NN
#   in/IN
#   the/DT
#   third/JJ
#   quarter/NN
#   from/IN
#   the/DT
#   second/JJ
#   quarter/NN
#   and/CC
#   (VP (VP was/VBD))
#   up/IN
#   3.8/CD
#   %/NN
#   from/IN
#   a/DT
#   year/NN
#   (VP ago/RB)
#   ./.)
# 19 None

# %% [markdown]
# A gerund is a word like “swimming” in the sentence “I have always enjoyed swimming.” The term refers to the “-ing” form of a verb when it functions as a noun

# %%
#Write a tag pattern to cover noun phrases that contain gerunds,
#e.g., the/DT receiving/VBG end/NN, assistant/NN managing/VBG editor/NN.
#Add these patterns to the grammar, one per line.
#Test your work using some tagged sentences of your own devising.

grammar = """
    NP: {<DT><VBG><NN>}    # chunk determiner, gerund, and noun
        {<NN><VBG><NN>}    # chunk noun, gerund, and noun
        # or {<DT|NN><VBG><NN>}
"""
cp = nltk.RegexpParser(grammar)
sentences = [[("the", "DT"), ("receiving", "VBG"), ("end", "NN")],
             [("assistant", "NN"),  ("managing", "VBG"),  ("editor", "NN")]]

for sent in sentences:
    print(cp.parse(sent))
# Out:
# (S (NP the/DT receiving/VBG end/NN))
# (S (NP assistant/NN managing/VBG editor/NN))
